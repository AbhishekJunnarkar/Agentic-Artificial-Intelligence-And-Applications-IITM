# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhishekJunnarkar/Agentic-Artificial-Intelligence-And-Applications-IITM/blob/main/Week2_lab_25thOctober_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Python statement
project_completed = True
in_class = True
is_class_boring = False
print(project_completed, in_class, is_class_boring)
project_completed
type(project_completed)

# %%
help(bool)

# %%
project_completed = False

# %%
x = 40
y = x / 3 # Basic division operator
print(type(x))
print(x)

# %%
z = x // 3 # Integer divion operator: This will result in int only
print(z)
print(type(z))

# %%
x % 3 # This modules operator will give the reminder as outcome

# %%
a = 2 ** 3 # Power operator
print(a)

# %%
# Conversion of data types
student_id = 'S'+str(2) # String concatination
print(student_id)

# %% [markdown]
# # Data structures in Python

# %%
# Lists - Ordered, mutable, versatile

# %%
electonic_devices = ["Laptop","Mobile", "Xbox"]
print(electonic_devices)

# %%
numbers = list(range(1,10))
print(numbers)

# %%
# make a star shape using *

# %%
list_chars = list('Python is great')
print(list_chars)
print(len(list_chars))

# %% [markdown]
# # Indexing in Python

# %%
list_chars[10] # note that lists 10th index is g

# %%
list_chars[-5]

# %%
a_str ='Python is great'
a_str[10]  # note that strings 10th index is g too

# %%
list_chars[:6] # Slicing result in list

# %%
a_str[:6] # Slicing result in string
a_str[7:12:2]
list_chars[7:12:2]

# %%
list_chars[::2]

# %%
a_str[::2]

# %%
list_fruits = ["apple", "banana", 'peach', 'pinapple' ]

# %% [markdown]
# # Tuple

# %%
uni_tuple = (5,)
print(uni_tuple)
print(type(uni_tuple))

# %%
print(list_fruits)
tuple_fruits = tuple(list_fruits[:3])
print(tuple_fruits)
f1, f2, f3 = tuple_fruits
print(f1, f2, f3)

# %%
more_fruits = tuple_fruits + ('orange', 'mango', 'apple')
print(more_fruits)

# %%
fruit_set = set(more_fruits)
print(fruit_set)

# %%
tuple_fruits = tuple_fruits*2
print(tuple_fruits)
print(type(tuple_fruits))

# %% [markdown]
# # Set

# %%
myset = set()
print(myset)
print(type(myset))

# %%
my_newset = {}
print(my_newset)
print(type(my_newset))

# %%
fruits = {"apple", "banana", "cherry"}
print(fruits)
print(type(fruits))

# %%
numbers = set([1,2,3,4,2,3])
print(numbers)

# %%
help(set)

# %%
help(tuple)
